# %% [raw]
# ---
# title: "Project: Exploratory analysis of clinical breast cancer patient data"
# author: "David B. Blumenthal, Anne Hartebrodt, Anna Möller"
# format:
#   revealjs:
#     echo: true
#     scrollable: true
#     number-sections: true
#     number-depth: 1
#     smaller: true
#     code-overflow: scroll
#     logo: input/FAU.png
#     footer: "Practical Skills in Computational Biology"
# jupyter: python3
# ---

# %% [markdown]
# ## Task 1: load and merge data
#
# - Use pandas to load the files `input/TCGA-BRCA.clinical.tsv` and `input/TCGA-BRCA.survival.tsv` which contain clinical and survival data for breast cancer patients, originally obtained from https://xenabrowser.net/datapages/?cohort=GDC%20TCGA%20Breast%20Cancer%20(BRCA)&removeHub=https%3A%2F%2Fxena.treehouse.gi.ucsc.edu%3A443.
# - Have a look at the data frames and identify appropriate columns for merging them.
# - Merge the two data frames.

# %% [markdown]
# ## Task 2: identify non-biological confounders of overall survival
#
# - Carry out a literature search to understand how the variable `OS.time` is defined in TCGA data.
# - Carry out a correlation analysis among the nunmeric variables in the merged data frame to identify variables that are correlated with `OS.time`.
# - Identify the variables with the strongest positive or negative correlations with `OS.time`. Can you explain the strong positive/negative correlations by referring to the definition of `OS.time` and the experimental of the TCGA study? This article may help you: https://doi.org/10.1016/j.cell.2018.02.052.
# - Which of the numeric variables in the merged data frames are legitimate features that could be used for training a machine learning model tasked to predict `OS.time`? Consider the problem of data leakage (https://doi.org/10.1038/s41592-024-02362-y) when answering this question.
# - After having completed all of these analysis steps, you will have identified non-biological confounders of `OS.time`.

# %% [markdown]
# ## Task 3: generate plots to visualize your findings
#
# - Generate appropriate plots that visualize the links between `OS.time` and the non-biological confounders identified in Task 1.3.
# - Save your visualization as a PDF file, combining several plots into one figure. If necessary, rename axis titles, x-, or y-labels. Ensure that all text inside the figure is readable. Use appropriate parameters to make the plots as beautiful as possible.

# %% [markdown]
# ## Task 4: turn into reproducible code
#
# - After having carried out Tasks 1–3, make your code fully reproducible, using the techniques from lecture 5.
